# %%
from game import penneys_game
from visuals.visualization import heatmap

# %%
database_loc = 'data/penney.db'

# %% [markdown]
# Generate a heatmap of the probabilities based on existing simulations of Penney's Game:

# %%
heatmap(database_loc)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 heatmap('data/penney.db')
#
# File c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\visuals\visualization.py:116, in heatmap(path_db)
#     112 n = prob_df['TimesPlayed'][0]
#     114 viz_input={'Cards':prob_p1card, 'Tricks':prob_p1trick, 'n':n}
# --> 116 create_viz(viz_input)
#     117 return
#
# File c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\visuals\visualization.py:106, in heatmap.<locals>.create_viz(dict)
#     104 plt.subplots_adjust(wspace=0.25)
#     105 plt.suptitle("Probability of Player 1 Winning Penney's Game (n="+str(n)+')', y=1.07, fontsize = 17)
# --> 106 plt.savefig('figures/heatmap_n'+str(n)+'.png', bbox_inches = 'tight', facecolor = 'white')
#     107 plt.show()
#
# ...

# %% [markdown]
# Generate new simulations and incorporate them into database and heatmap:

# %%
penneys_game('data/penney.db',ngames=1000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 penneys_game('data/penney.db',ngames=1000)
#
# File c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\game.py:8, in penneys_game(path, ngames, seed)
#       6 simulation = sim(ngames, seed)
#       7 db_path = make_database(simulation, path)
# ----> 8 heatmap(db_path)
#      10 return
#
# File c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\visuals\visualization.py:116, in heatmap(path_db)
#     112 n = prob_df['TimesPlayed'][0]
#     114 viz_input={'Cards':prob_p1card, 'Tricks':prob_p1trick, 'n':n}
# --> 116 create_viz(viz_input)
#     117 return
#
# File c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\visuals\visualization.py:106, in heatmap.<locals>.create_viz(dict)
# ...

# %% [markdown]
# Left to do:
# - Separate into two functions so that one generates heatmap and one simulates _n_ additional games
# - Fix the file structure error in heatmap
