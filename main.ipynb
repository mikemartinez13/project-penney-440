# %%
from play import play
from visualization import heatmap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from play import play
#       2 from visualization import heatmap
#
# File c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\play.py:2
#       1 from penney_db1 import make_database
# ----> 2 from simulation import sim
#       4 def play(path, ngames: int, seed = 0) -> None:
#       5     simulation = sim(ngames, seed)
#
# ImportError: cannot import name 'sim' from 'simulation' (c:\Users\micha\OneDrive - William & Mary\Desktop\Fall_2024\DATA440\project-penney-440\simulation.py)

# %%
play('data/example_file.db', 30000)

# %%
heatmap('data/example_file.db')

# %%
from importlib import reload

# %%
import processing_updated as proc
import visualization as vis
reload(proc)
reload(vis)
# Out:
# <module 'visualization' from 'c:\\Users\\micha\\OneDrive - William & Mary\\Desktop\\Fall_2024\\DATA440\\project-penney-440\\visualization.py'>

# %%
proc.play(100)

# %%
vis.make_heatmap()
# Out:
# (<Figure size 1200x600 with 3 Axes>,
#  array([<Axes: title={'center': 'My Chance of Winning (by Cards)\n(n=100)'}, xlabel='My Guesses', ylabel='Opponent Guesses'>,
#         <Axes: title={'center': 'My Chance of Winning (by Tricks)\n(n=100)'}, xlabel='My Guesses'>],
#        dtype=object))
