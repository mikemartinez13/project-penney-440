# %%
from importlib import reload

# %%
import processing_updated as proc
import visualization as vis
reload(proc)
reload(vis)
# Out:
# <module 'visualization' from '/Users/kirinmackey/Desktop/project_penney/visualization.py'>

# %%
proc.play(int(1e6))

# %%
vis.make_heatmap()
# Out:
# (<Figure size 864x432 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'My Chance of Winning (by Cards)\n(n=1000000)'}, xlabel='My Guesses', ylabel='Opponent Guesses'>,
#         <AxesSubplot:title={'center':'My Chance of Winning (by Tricks)\n(n=1000000)'}, xlabel='My Guesses'>],
#        dtype=object))
